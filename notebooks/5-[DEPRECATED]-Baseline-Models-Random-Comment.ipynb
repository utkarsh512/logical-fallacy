# %% [markdown]
# __Notes__: This notebook is deprecated.

# %% [markdown]
# # Classifying Random Internet Comment with baseline models
# For this task, please change the block in `Ad-hominem-fallacies/experiments/classification_experiments.py` from
# ```python
# if __name__ == '__main__':
#     main()
# ```
# to
# ```python
# if __name__ == '__main__':
#     main2()
# ```

# %%
# mounting Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %%shell
# cd /content/gdrive/'My Drive'/
# rm -rf Ad-hominem-fallacies
# git clone https://github.com/utkarsh512/Ad-hominem-fallacies.git
# Out:
# Cloning into 'Ad-hominem-fallacies'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 194 (delta 54), reused 0 (delta 0), pack-reused 106
# Receiving objects: 100% (194/194), 37.50 MiB | 15.71 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# Checking out files: 100% (78/78), done.

# %%
# %%shell
# cd /content/gdrive/'My Drive'/Ad-hominem-fallacies/experiments
# pip install virtualenv
# virtualenv env --python=python3
# source env/bin/activate
# pip install lda scipy==1.1.0 nltk==3.2.5
# Out:
# ...
# created virtual environment CPython3.7.10.final.0-64 in 6350ms
#   creator CPython3Posix(dest=/content/gdrive/My Drive/Ad-hominem-fallacies/experiments/env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.0.1, setuptools==54.1.2, wheel==0.36.2
#   activators BashActivator,CShellActivator,FishActivator,PowerShellActivator,PythonActivator,XonshActivator
# ...
#   Using cached lda-2.0.0-cp37-cp37m-manylinux1_x86_64.whl (351 kB)
# ...
#   Using cached scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
# ...
#   Using cached nltk-3.2.5-py3-none-any.whl
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached numpy-1.20.1-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
# ...
#   Using cached pbr-3.1.1-py2.py3-none-any.whl (99 kB)
# ...

# %%
# %%shell
# cd /content/gdrive/'My Drive'/Ad-hominem-fallacies/experiments
# wget https://public.ukp.informatik.tu-darmstadt.de/ih/RedditChangeMyView2017/en-top100k.embeddings.pkl.gz
# Out:
# --2021-03-17 05:19:55--  https://public.ukp.informatik.tu-darmstadt.de/ih/RedditChangeMyView2017/en-top100k.embeddings.pkl.gz
# Resolving public.ukp.informatik.tu-darmstadt.de (public.ukp.informatik.tu-darmstadt.de)... 130.83.167.186
# Connecting to public.ukp.informatik.tu-darmstadt.de (public.ukp.informatik.tu-darmstadt.de)|130.83.167.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 152970296 (146M) [application/octet-stream]
# Saving to: ‘en-top100k.embeddings.pkl.gz’
#
# en-top100k.embeddin 100%[===================>] 145.88M  31.7MB/s    in 7.4s
#
# 2021-03-17 05:20:04 (19.7 MB/s) - ‘en-top100k.embeddings.pkl.gz’ saved [152970296/152970296]

# %%
# %%shell
# cd /content/gdrive/'My Drive'/Ad-hominem-fallacies/experiments
# tar -xvf sampled-threads-ah-delta-context3.tar.bz2 -C data/
# Out:
# sampled-threads-ah-delta-context3/
# sampled-threads-ah-delta-context3/1213_delta_t1_dm10vxo.json
# sampled-threads-ah-delta-context3/175_ah_t1_dlqrux0.json
# sampled-threads-ah-delta-context3/647_ah_t1_cqy072s.json
# sampled-threads-ah-delta-context3/261_ah_t1_cj87dst.json
# sampled-threads-ah-delta-context3/134_delta_t1_dmnatwa.json
# sampled-threads-ah-delta-context3/1070_ah_t1_di63b9y.json
# sampled-threads-ah-delta-context3/846_ah_t1_cvyhbbh.json
# sampled-threads-ah-delta-context3/575_delta_t1_cgjh9o2.json
# sampled-threads-ah-delta-context3/284_ah_t1_d98wq0g.json
# sampled-threads-ah-delta-context3/473_ah_t1_cjkayyc.json
# sampled-threads-ah-delta-context3/871_delta_t1_djbfsuw.json
# sampled-threads-ah-delta-context3/222_ah_t1_dlq9jlp.json
# sampled-threads-ah-delta-context3/482_ah_t1_clrfkvu.json
# sampled-threads-ah-delta-context3/1103_delta_t1_dmk47tv.json
# sampled-threads-ah-delta-context3/821_ah_t1_cyb6qi4.json
# ...

# %%
# !nvidia-smi
# Out:
# Wed Mar 17 04:15:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %%shell
# cd /content/gdrive/'My Drive'/Ad-hominem-fallacies/experiments
# pip install lda
# python classification_experiments.py --model cnn --indir /content/gdrive/MyDrive/DL/dataset/comments.log --outdir /content/gdrive/MyDrive/DL/dataset/
# Out:
# ...
# 2021-03-17 05:21:15.254628: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From classification_experiments.py:148: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2021-03-17 05:21:16.939424: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-17 05:21:16.940275: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-17 05:21:16.970198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# %%shell
# cd /content/gdrive/'My Drive'/Ad-hominem-fallacies/experiments
# pip install lda
# python classification_experiments.py --model bilstm --indir /content/gdrive/MyDrive/DL/dataset/comments.log --outdir /content/gdrive/MyDrive/DL/dataset/
# Out:
# ...
# 2021-03-17 05:26:57.852128: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From classification_experiments.py:148: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2021-03-17 05:26:59.495210: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-17 05:26:59.496117: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-17 05:26:59.528416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
