# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
# %%shell
# pip install glom

# %%
# %cd /content/gdrive/MyDrive/DL/CreateDebate

# %%
# !mkdir religion

# %%
# !python scrape.py --data_dir religion --tag Religion --page_count 30 --state both

# %%
# !mkdir technology

# %%
# !python scrape.py --data_dir technology --tag Technology --page_count 10 --state both

# %%
# !mkdir sports

# %%
# !python scrape.py --data_dir sports --tag Sports --page_count 7 --state both

# %%
# !mkdir comedy
# !python scrape.py --data_dir comedy --tag Comedy --page_count 5 --state both

# %%
# !mkdir business
# !python scrape.py --data_dir business --tag Business --page_count 4 --state both

# %%
# !mkdir travel
# !python scrape.py --data_dir travel --tag Travel --page_count 2 --state both

# %%
# !mkdir shopping
# !python scrape.py --data_dir shopping --tag Shopping --page_count 2 --state both

# %%
# !mkdir health
# !python scrape.py --data_dir health --tag Health --page_count 7 --state both

# %%
# !python scrape.py --data_dir politics2 --tag Politics --page_count 110 --state both
